# %% [markdown]
# ## Convert patchmaster .dat to .nwb form at and add metadata and experimental details

# %% [markdown]
# ### Import modules and setup filenames

# %%
# import modules
import numpy as np
import os
import pandas as pd
import pynwb
import roman
import sys
import uuid

from datetime import datetime
from dateutil.tz import tzlocal
from pynwb import NWBHDF5IO, NWBFile
from pynwb.file import Subject

## add path to parent directory to import conversion module
sys.path.append('..') 
from src.x_to_nwb import convert

# %%
# set files to look at for testing
cell_id = 'ASH189' # neuron type + recording number, should be a unique identifier within this dataset

# TO DO - eventually want to be able to loop through all the cells in the metadata spreadsheet

# %% [markdown]
# ### Define functions

# %%
def import_recording_metadata(fname, cell_id, start_row):
    '''
    import_metadata: gets all the metadata from a specific recording with the input cell id 
    '''
    #import excel file
    df = pd.read_excel(fname_metadata, skiprows = range(start_row), header=[0,1], sheet_name='Recordings-MetaData')

    #clean up the column names
    colname_top = df.columns.get_level_values(level=0).str.replace('Unnamed.*','',regex=True)
    colname_bottom = df.columns.get_level_values(level=1).str.replace('Unnamed.*','',regex=True)
    df.columns = [colname_top, colname_bottom]
    df.columns = df.columns.map(''.join)
    
    #select the row containing the relevant experiment info
    exp_info = df.loc[df['Cell ID'] == cell_id]

    return exp_info

# %%
def import_subject_metadata(fname, exp_info):
    '''
    import_subject_metadata: gets subject info like genotype, worm dimensions, id
    and exports as dict for input into the nwb file
    '''
    #get cell id
    cell_id = exp_info['Cell ID'].values[0]
    cell_type = exp_info['Cell'].values[0]
    
    #get genotype using strain ID
    strain = exp_info['Strain'].values[0]
    df = pd.read_excel(fname, sheet_name='StrainsdB')
    genotype = df['Genotype'][df['Strain'] == strain].values[0]
    
    #get worm dimensions
    vals = exp_info.filter(like='µm').values[0]
    keys = ['length (µm)','width (µm)','area (µm)']
    dims = dict(zip(keys,vals))
        
    #compile description
    descript = {**{'cell type': cell_type}, **dims}
    nan_vals = ['no data','nd']
    for k in descript:
        if descript[k] in nan_vals:
            descript[k] = 'nan'

    subject_metadata = {'subject_id': cell_id, 'description': str(descript), 'genotype': genotype}
    
    return subject_metadata

# %%
def get_ingredients(fname, rec_data, sheet_name, col_name):
    #import values for experiment
    df = pd.read_excel(fname, header=[0,1], sheet_name=sheet_name)
    solution = rec_data[col_name].values[0]

    #get ingredients list for each solution
    if solution == 'np':
        ingredients = 'no fast perfusion, gravity fed'
    elif solution not in df:
        ingredients = solution
    else:
        ingredients = dict(zip(df[solution]['Ingredients'], df[solution]['Molarity']))

    #output result
    return ingredients

# %%
def import_solution_metadata(fname, rec_data):
    sol_int = get_ingredients(fname, rec_data, 'I-SolutionsdB', 'I-soln')
    sol_ext_ctl = get_ingredients(fname, rec_data, 'E-SolutionsdB', 'E-soln-ctl')
    sol_ext_exp = get_ingredients(fname, rec_data, 'E-SolutionsdB', 'E-soln-exp')
    
    solution_metadata = {'Internal solution': sol_int, 
                         'External solution - control': sol_ext_ctl,
                         'External solution - experimental': sol_ext_exp}
    
    return solution_metadata

# %%
def get_dat_filename(date_raw):
    '''
    get_dat_filename: converts string in dd-mm-yy format with the month stored
    as roman numerals into yy_mm_dd format with all integer values 
    '''    
    # convert roman numerals to string
    date_split = date_raw.split('-') 
    date_split[1] = str(roman.fromRoman(date_split[1]))
    
    #convert to be yy-mm-dd format for .dat files
    date = datetime.strptime(' '.join(date_split), "%d %m %y").strftime("%y-%m-%d")
    
    return date

# %% [markdown]
# ### Compile metadata

# %%
# load the metadata spreadsheet
fname_metadata = '..//test_data//ASH-metadata_12_III_29.xls'
rec_data = import_recording_metadata(fname_metadata, cell_id, start_row=13)

# get metadata details
subj_data = import_subject_metadata(fname_metadata, rec_data)
sol_data = import_solution_metadata(fname_metadata, rec_data)

# save all metadata fields
all_metadata = {'species': 'C. elegans',
                'genotype': subj_data['genotype'],
                'subject_id': subj_data['subject_id'],
                'subject_description': subj_data['description'],
                'experiment_description':'intracellular whole-cell patch clamp recordings in ASH neurons of C. elegans',
                'session_description': 'PLACEHOLDER',
                'lab': 'Goodman Lab',
                'institution': 'Stanford University',
                'protocol': 'similar to Goodman et al, 1998 Neuron, doi: 10.1016/s0896-6273(00)81014-4', # TO DO - include more details?
                'related_publications': 'Geffeney et al, Neuron 2011, doi: 10.1016/j.neuron.2011.06.038'
               }

# TO DO - add electrode details?
# TO DO - add field for mechanical stimuluation for relevant files?
# TO DO - add more details to protocol? or to stimulus traces?
    # start with ct-ivq 'on cell'
    # followed by ct-ivq 'whole cell'
    # average traces from first IVq subtracted from averaged traces of second IVq to remove capacitance artifacts
    # ct protocol (capacity transient) is a series of +10 mV and -10 mV voltage pulses to measure capacitance and to estimate series resistance.

# %% [markdown]
# ### Generate nwb file

# %%
# get file name of raw data
rec_date = get_dat_filename(rec_data['Recording Date'].values[0])

# check that file exists
fname_dat = f"..//test_data//{rec_date}.dat"
if not os.path.isfile(fname_dat):
    rec_date = rec_date.replace('-','_')
    fname_dat = f"..//test_data//{rec_date}.dat"

if not os.path.isfile(fname_dat):
    raise ValueError(f"The file {fname_dat }does not exist")

# run converter - TO DO
convert(fname_dat, overwrite=True, existingNWBData=all_metadata)
# Out:
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_bundle.py:59: UserWarning: The DAT file version 'v2x32, 18-Jan-2008' of '..//test_data//08-10-30.dat' might be incompatible and therefore read/interpretation errors are possible.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:370: UserWarning: Skipping amp check because 'v2x32, 18-Jan-2008' does not contain a separate amp structure.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 100110001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 100140001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 100170001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 100200001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 100230001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 100240001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 100270001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 10 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 10 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 13 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 13 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 16 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 16 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 19 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 19 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 22 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 22 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 23 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 23 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 26 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 26 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200110001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200140001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200170001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200170002 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200170003 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200170004 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200170005 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200170006 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200170007 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200170008 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200170009 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200170010 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200170011 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200180001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200180002 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200180003 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200180004 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200180005 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200180006 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200180007 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200180008 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200180009 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200180010 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200180011 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200190001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200200001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200230001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200260001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200290001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200320001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200350001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200380001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200410001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200440001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200470001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200500001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200530001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200560001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200590001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200620001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200650001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200680001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200710001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200740001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200770001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200800001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200830001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 200860001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 37 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 37 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 40 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 40 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 43 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 43 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 44 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 44 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 45 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 45 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 46 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 46 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 49 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 49 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 52 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 52 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 55 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 55 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 58 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 58 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 61 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 61 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 64 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 64 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 67 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 67 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 70 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 70 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 73 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 73 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 76 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 76 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 79 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 79 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 82 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 82 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 85 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 85 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 88 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 88 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 91 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 91 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 94 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 94 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 97 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 97 and ChannelRecord index 1.
#   warnings.warn(
# Increment mode Alternate is not supported.
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Increment mode Alternate is not supported.
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Can not yet recreate stimset Miv_VC
# Increment mode Alternate is not supported.
# Can not yet recreate stimset Miv_VC
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 100 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 100 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 103 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 103 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 106 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 106 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 109 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 109 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 112 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 112 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 300010001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 300010002 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 300010003 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 300010004 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 300010005 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 300010006 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 300010007 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 300010008 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 300010009 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 300010010 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 115 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 115 and ChannelRecord index 1.
#   warnings.warn(
# '..//test_data//08-10-30.nwb'

# %% [markdown]
# ### Inspect the final nwb file

# %%
# load the existing nwb files
fname_nwb = f"..//test_data//{rec_date}-1.nwb"
io = NWBHDF5IO(fname_nwb, 'r')
nwbfile = io.read()
print(nwbfile)
# Out:
# root pynwb.file.NWBFile at 0x140539949737296
# Fields:
#   acquisition: {
#     index_0000 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0001 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0002 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0003 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0004 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0005 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0006 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0007 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0008 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0009 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0010 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0011 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0012 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0013 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0014 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0015 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0016 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0017 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0018 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0019 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0020 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0021 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0022 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0023 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0024 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0025 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0026 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0027 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0028 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0029 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0030 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0031 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0032 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0033 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0034 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0035 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0036 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0037 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0038 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0039 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0040 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0041 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0042 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0043 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0044 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0045 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0046 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0047 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0048 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0049 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0050 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0051 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0052 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0053 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0054 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0055 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0056 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0057 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0058 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0059 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0060 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0061 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0062 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0063 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0064 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0065 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0066 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0067 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0068 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0069 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0070 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0071 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0072 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0073 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0074 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0075 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0076 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0077 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0078 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0079 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0080 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0081 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0082 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0083 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0084 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0085 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0086 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0087 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0088 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0089 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0090 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0091 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0092 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0093 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0094 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0095 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0096 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0097 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0098 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0099 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0100 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0101 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0102 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0103 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0104 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0105 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0106 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0107 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0108 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0109 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0110 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0111 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0112 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0113 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0114 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0115 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0116 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0117 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0118 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0119 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0120 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0121 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0122 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0123 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0124 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0125 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0126 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0127 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0128 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0129 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0130 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0131 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0132 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0133 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0134 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0135 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0136 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0137 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0138 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0139 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0140 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0141 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0142 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0143 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0144 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0145 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0146 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0147 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0148 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0149 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0150 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0151 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0152 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0153 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0154 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0155 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0156 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0157 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0158 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0159 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0160 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0161 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0162 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0163 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0164 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0165 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0166 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0167 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0168 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0169 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0170 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0171 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0172 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0173 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0174 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0175 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0176 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0177 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0178 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0179 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0180 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0181 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0182 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0183 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0184 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0185 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0186 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0187 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0188 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0189 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0190 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0191 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0192 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0193 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0194 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0195 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0196 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0197 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0198 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0199 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0200 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0201 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0202 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0203 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0204 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0205 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0206 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0207 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0208 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0209 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0210 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0211 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0212 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0213 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0214 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0215 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0216 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0217 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0218 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0219 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0220 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0221 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0222 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0223 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0224 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_0225 <class 'pynwb.icephys.VoltageClampSeries'>
#   }
#   devices: {
#     EPC10-1-0 with LIH1600 <class 'pynwb.device.Device'>
#   }
#   experiment_description: intracellular whole-cell patch clamp recordings in ASH neurons of C. elegans
#   file_create_date: [datetime.datetime(2021, 8, 5, 9, 34, 40, 85984, tzinfo=tzoffset(None, -14400))]
#   icephys_electrodes: {
#     Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>,
#     Electrode 1 <class 'pynwb.icephys.IntracellularElectrode'>
#   }
#   identifier: 22530dc12fec76e7a64a868ed7724551115170280fd3b41752fb4de6a0adafaf
#   institution: Stanford University
#   lab: Goodman Lab
#   notes: data generated with PatchMaster v2x32, 18-Jan-2008
#   protocol: similar to Goodman et al, 1998 Neuron, doi: 10.1016/s0896-6273(00)81014-4
#   related_publications: ['Geffeney et al, Neuron 2011, doi: 10.1016/j.neuron.2011.06.038']
#   session_description: PLACEHOLDER
#   session_start_time: 2008-10-30 06:59:55.922000+00:00
#   source_script: {
#     "git_revision": "(main) e077397",
#     "package_version": "Unknown",
#     "repo": "https://github.com/byte-physics/x-to-nwb"
# }
#   source_script_file_name: conversion.py
#   stimulus: {
#     index_0000 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0001 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0002 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0003 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0004 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0005 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0006 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0007 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0008 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0009 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0010 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0011 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0012 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0013 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0014 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0015 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0016 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0017 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0018 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0019 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0020 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0021 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0022 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0023 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0024 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0025 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0026 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0027 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0028 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0029 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0030 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0031 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0032 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0033 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0034 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0035 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0036 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0037 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0038 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0039 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0040 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0041 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0042 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0043 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0044 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0045 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0046 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0047 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0048 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0049 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0050 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0051 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0052 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0053 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0054 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0055 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0056 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0057 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0058 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0059 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0060 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0061 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0062 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0063 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0064 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0065 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0066 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0067 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0068 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0069 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0070 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0071 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0072 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0073 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0074 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0075 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0076 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0077 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0078 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0079 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0080 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0081 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0082 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0083 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0084 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0085 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0086 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0087 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0088 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0089 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0090 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0091 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0092 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0093 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0094 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0095 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0096 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0097 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0098 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0099 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0100 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0101 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0102 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0103 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0104 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0105 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0106 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0107 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0108 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0109 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0110 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0111 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0112 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0113 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0114 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0115 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0116 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0117 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0118 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0119 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0120 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0121 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0122 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0123 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0124 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0125 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0126 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0127 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0128 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0129 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0130 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0131 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0132 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0133 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0134 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0135 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0136 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0137 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0138 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0139 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0140 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0141 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0142 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0143 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0144 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0145 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0146 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0147 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0148 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0149 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0150 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0151 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0152 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0153 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0154 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0155 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0156 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0157 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0158 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0159 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0160 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0161 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0162 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0163 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0164 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0165 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0166 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0167 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0168 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0169 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0170 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0171 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0172 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0173 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0174 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0175 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0176 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0177 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0178 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0179 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0180 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0181 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0182 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0183 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0184 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0185 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0186 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0187 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0188 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0189 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0190 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0191 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0192 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0193 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0194 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0195 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0196 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0197 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0198 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0199 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0200 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0201 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0202 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0203 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0204 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0205 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0206 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0207 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0208 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0209 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0210 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0211 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0212 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0213 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0214 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0215 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0216 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0217 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0218 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0219 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0220 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0221 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0222 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0223 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0224 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_0225 <class 'pynwb.icephys.VoltageClampStimulusSeries'>
#   }
#   subject: subject pynwb.file.Subject at 0x140540056608000
# Fields:
#   description: {'cell type': 'ASHL', 'length (µm)': 666.3801, 'width (µm)': 42.3846, 'area (µm)': 127.1538}
#   genotype: osm-10:rtIs97
#   species: C. elegans
#   subject_id: ASH189
#
#   sweep_table: sweep_table <class 'pynwb.icephys.SweepTable'>
#   timestamps_reference_time: 2008-10-30 06:59:55.922000+00:00
