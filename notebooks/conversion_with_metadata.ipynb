# %% [markdown]
# ## Convert patchmaster .dat to .nwb form at and add metadata and experimental details

# %% [markdown]
# ### Import modules and setup filenames

# %%
# import modules
import numpy as np
import pandas as pd
import pynwb
import roman
import sys
import uuid

from datetime import datetime
from dateutil.tz import tzlocal
from pynwb import NWBHDF5IO, NWBFile
from pynwb.file import Subject

## add path to parent directory to import conversion module
sys.path.append('..') 
from src.x_to_nwb import convert

# %%
# set files to look at for testing
cell_id = 'ASH301' # neuron type + recording number, should be a unique identifier within this dataset

# TO DO - eventually want to be able to loop through all the cells in the metadata spreadsheet

# %% [markdown]
# ### Define functions

# %%
def import_recording_metadata(fname, cell_id, start_row):
    '''
    import_metadata: gets all the metadata from a specific recording with the input cell id 
    '''
    #import excel file
    df = pd.read_excel(fname_metadata, skiprows = range(start_row), header=[0,1], sheet_name='Recordings-MetaData')

    #clean up the column names
    colname_top = df.columns.get_level_values(level=0).str.replace('Unnamed.*','',regex=True)
    colname_bottom = df.columns.get_level_values(level=1).str.replace('Unnamed.*','',regex=True)
    df.columns = [colname_top, colname_bottom]
    df.columns = df.columns.map(''.join)
    
    #select the row containing the relevant experiment info
    exp_info = df.loc[df['Cell ID'] == cell_id]

    return exp_info

# %%
def import_subject_metadata(fname, exp_info):
    '''
    import_subject_metadata: gets subject info like genotype, worm dimensions, id
    and exports as dict for input into the nwb file
    '''
    #get cell id
    cell_id = exp_info['Cell ID'].values[0]
    cell_type = exp_info['Cell'].values[0]
    
    #get genotype using strain ID
    strain = exp_info['Strain'].values[0]
    df = pd.read_excel(fname, sheet_name='StrainsdB')
    genotype = df['Genotype'][df['Strain'] == strain].values[0]
    
    #get worm dimensions
    vals = exp_info.filter(like='µm').values[0]
    keys = ['length (µm)','width (µm)','area (µm)']
    dims = dict(zip(keys,vals))
        
    #compile description
    descript = {**{'cell type': cell_type}, **dims}
    nan_vals = ['no data','nd']
    for k in descript:
        if descript[k] in nan_vals:
            descript[k] = 'nan'

    subject_metadata = {'subject_id': cell_id, 'description': str(descript), 'genotype': genotype}
    
    return subject_metadata

# %%
def get_ingredients(fname, rec_data, sheet_name, col_name):
    #import values for experiment
    df = pd.read_excel(fname, header=[0,1], sheet_name=sheet_name)
    solution = rec_data[col_name].values[0]

    #get ingredients list for each solution
    if solution == 'np':
        ingredients = 'no fast perfusion, gravity fed'
    else:
        ingredients = dict(zip(df[solution]['Ingredients'], df[solution]['Molarity']))

    #output result
    return ingredients

# %%
def import_solution_metadata(fname, rec_data):
    sol_int = get_ingredients(fname, rec_data, 'I-SolutionsdB', 'I-soln')
    sol_ext_ctl = get_ingredients(fname, rec_data, 'E-SolutionsdB', 'E-soln-ctl')
    sol_ext_exp = get_ingredients(fname, rec_data, 'E-SolutionsdB', 'E-soln-exp')
    
    solution_metadata = {'Internal solution': sol_int, 
                         'External solution - control': sol_ext_ctl,
                         'External solution - experimental': sol_ext_exp}
    
    return solution_metadata

# %%
def get_dat_filename(date_raw):
    '''
    get_dat_filename: converts string in dd-mm-yy format with the month stored
    as roman numerals into yy_mm_dd format with all integer values 
    '''    
    # convert roman numerals to string
    date_split = date_raw.split('-') 
    date_split[1] = str(roman.fromRoman(date_split[1]))
    
    #convert to be yy-mm-dd format for .dat files
    date = datetime.strptime(' '.join(date_split), "%d %m %y").strftime("%y_%m_%d")
    
    return date

# %% [markdown]
# ### Compile metadata

# %%
# load the metadata spreadsheet
fname_metadata = '..//test_data//ASH-metadata_12_III_29.xls'
rec_data = import_recording_metadata(fname_metadata, cell_id, start_row=13)

# get metadata details
subj_data = import_subject_metadata(fname_metadata, rec_data)
sol_data = import_solution_metadata(fname_metadata, rec_data)

# save all metadata fields
all_metadata = {'species': 'C. elegans',
                'genotype': subj_data['genotype'],
                'subject_id': subj_data['subject_id'],
                'subject_description': subj_data['description'],
                'experiment_description':'intracellular whole-cell patch clamp recordings in ASH neurons of C. elegans',
                'session_description': 'PLACEHOLDER',
                'lab': 'Goodman Lab',
                'institution': 'Stanford University',
                'protocol': 'similar to Goodman et al, 1998 Neuron, doi: 10.1016/s0896-6273(00)81014-4', # TO DO - include more details?
                'related_publications': 'Geffeney et al, Neuron 2011, doi: 10.1016/j.neuron.2011.06.038'
               }

# TO DO - add electrode details?
# TO DO - add field for mechanical stimuluation for relevant files?
# TO DO - add more details to protocol? or to stimulus traces?
    # start with ct-ivq 'on cell'
    # followed by ct-ivq 'whole cell'
    # average traces from first IVq subtracted from averaged traces of second IVq to remove capacitance artifacts
    # ct protocol (capacity transient) is a series of +10 mV and -10 mV voltage pulses to measure capacitance and to estimate series resistance.

# %% [markdown]
# ### Generate nwb file

# %%
# get file name of raw data
rec_date = get_dat_filename(rec_data['Recording Date'].values[0])
fname_dat = f"..//test_data//{rec_date}.dat"

# run converter - TO DO
convert(fname_dat, overwrite=True, existingNWBData=all_metadata)
# Out:
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_bundle.py:59: UserWarning: The DAT file version 'v2x32, 18-Jan-2008' of '..//test_data//10_03_19.dat' might be incompatible and therefore read/interpretation errors are possible.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:370: UserWarning: Skipping amp check because 'v2x32, 18-Jan-2008' does not contain a separate amp structure.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1011001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1011002 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1011003 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1011004 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1011005 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1011006 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1011007 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1011008 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1011009 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1011010 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1012001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1012002 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1012003 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1012004 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1012005 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1012006 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1012007 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1012008 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1012009 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1012010 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1013001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1013002 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1013003 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1013004 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1013005 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1013006 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1013007 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1013008 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1013009 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1013010 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1014001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1014002 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1014003 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1014004 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1014005 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1014006 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1014007 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1014008 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1014009 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 1014010 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 10 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 10 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 11 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 11 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 12 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 12 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 13 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 13 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2016001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2016002 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2016003 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2016004 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2016005 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2016006 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2016007 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2016008 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2016009 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2016010 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2017001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2017002 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2017003 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2017004 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2017005 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2017006 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2017007 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2017008 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2017009 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2017010 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2018001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2018002 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2018003 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2018004 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2018005 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2018006 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2018007 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2018008 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2018009 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2018010 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2019001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2019002 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2019003 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2019004 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2019005 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2019006 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2019007 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2019008 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2019009 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2019010 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2020001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2021001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2021002 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2021003 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2021004 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2021005 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2030001 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2030002 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2030003 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2030004 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2030005 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2030006 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2030007 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2030008 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2030009 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/DatConverter.py:163: UserWarning: Unit and clamp mode does not match for 2030010 (V unit vs. V_CLAMP_MODE
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 31 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 31 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 32 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 32 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 33 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 33 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 34 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 34 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 35 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 35 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 36 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 36 and ChannelRecord index 1.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 45 and ChannelRecord index 0.
#   warnings.warn(
# /Users/stephanieprince/Desktop/GSoCproject/GSoC_2021_OSB_NWB/notebooks/../src/x_to_nwb/hr_stimsetgenerator.py:58: UserWarning: Unsupported ActualDacChannels lengths for sweep index 45 and ChannelRecord index 1.
#   warnings.warn(
# '..//test_data//10_03_19.nwb'

# %% [markdown]
# ### Inspect the final nwb file

# %%
# load the existing nwb files
fname_nwb = f"..//test_data//{rec_date}-1.nwb"
io = NWBHDF5IO(fname_nwb, 'r')
nwbfile = io.read()
print(nwbfile)
# Out:
# root pynwb.file.NWBFile at 0x140498981748112
# Fields:
#   acquisition: {
#     index_000 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_001 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_002 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_003 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_004 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_005 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_006 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_007 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_008 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_009 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_010 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_011 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_012 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_013 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_014 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_015 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_016 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_017 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_018 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_019 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_020 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_021 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_022 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_023 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_024 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_025 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_026 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_027 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_028 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_029 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_030 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_031 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_032 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_033 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_034 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_035 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_036 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_037 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_038 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_039 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_040 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_041 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_042 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_043 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_044 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_045 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_046 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_047 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_048 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_049 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_050 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_051 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_052 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_053 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_054 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_055 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_056 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_057 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_058 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_059 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_060 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_061 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_062 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_063 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_064 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_065 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_066 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_067 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_068 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_069 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_070 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_071 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_072 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_073 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_074 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_075 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_076 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_077 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_078 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_079 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_080 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_081 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_082 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_083 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_084 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_085 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_086 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_087 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_088 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_089 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_090 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_091 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_092 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_093 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_094 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_095 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_096 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_097 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_098 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_099 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_100 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_101 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_102 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_103 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_104 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_105 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_106 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_107 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_108 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_109 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_110 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_111 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_112 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_113 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_114 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_115 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_116 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_117 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_118 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_119 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_120 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_121 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_122 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_123 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_124 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_125 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_126 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_127 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_128 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_129 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_130 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_131 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_132 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_133 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_134 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_135 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_136 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_137 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_138 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_139 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_140 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_141 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_142 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_143 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_144 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_145 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_146 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_147 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_148 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_149 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_150 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_151 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_152 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_153 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_154 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_155 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_156 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_157 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_158 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_159 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_160 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_161 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_162 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_163 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_164 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_165 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_166 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_167 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_168 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_169 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_170 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_171 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_172 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_173 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_174 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_175 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_176 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_177 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_178 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_179 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_180 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_181 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_182 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_183 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_184 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_185 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_186 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_187 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_188 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_189 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_190 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_191 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_192 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_193 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_194 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_195 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_196 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_197 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_198 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_199 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_200 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_201 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_202 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_203 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_204 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_205 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_206 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_207 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_208 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_209 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_210 <class 'pynwb.icephys.VoltageClampSeries'>,
#     index_211 <class 'pynwb.icephys.VoltageClampSeries'>
#   }
#   devices: {
#     EPC10-1-0 with LIH1600 <class 'pynwb.device.Device'>
#   }
#   experiment_description: intracellular whole-cell patch clamp recordings in ASH neurons of C. elegans
#   file_create_date: [datetime.datetime(2021, 7, 22, 10, 5, 2, 442293, tzinfo=tzoffset(None, -14400))]
#   icephys_electrodes: {
#     Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>,
#     Electrode 1 <class 'pynwb.icephys.IntracellularElectrode'>
#   }
#   identifier: 4d963159e199300f61d9f9760c8976eb502ce5846a446055858023eed4adc1ca
#   institution: Stanford University
#   lab: Goodman Lab
#   notes: data generated with PatchMaster v2x32, 18-Jan-2008
#   protocol: similar to Goodman et al, 1998 Neuron, doi: 10.1016/s0896-6273(00)81014-4
#   related_publications: ['Geffeney et al, Neuron 2011, doi: 10.1016/j.neuron.2011.06.038']
#   session_description: PLACEHOLDER
#   session_start_time: 2010-03-19 06:37:08.042999+00:00
#   source_script: {
#     "git_revision": "(main) 971617f",
#     "package_version": "Unknown",
#     "repo": "https://github.com/byte-physics/x-to-nwb"
# }
#   source_script_file_name: conversion.py
#   stimulus: {
#     index_000 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_001 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_002 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_003 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_004 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_005 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_006 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_007 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_008 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_009 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_010 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_011 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_012 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_013 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_014 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_015 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_016 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_017 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_018 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_019 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_020 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_021 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_022 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_023 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_024 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_025 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_026 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_027 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_028 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_029 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_030 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_031 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_032 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_033 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_034 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_035 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_036 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_037 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_038 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_039 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_040 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_041 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_042 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_043 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_044 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_045 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_046 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_047 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_048 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_049 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_050 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_051 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_052 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_053 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_054 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_055 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_056 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_057 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_058 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_059 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_060 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_061 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_062 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_063 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_064 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_065 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_066 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_067 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_068 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_069 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_070 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_071 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_072 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_073 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_074 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_075 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_076 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_077 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_078 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_079 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_080 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_081 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_082 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_083 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_084 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_085 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_086 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_087 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_088 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_089 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_090 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_091 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_092 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_093 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_094 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_095 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_096 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_097 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_098 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_099 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_100 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_101 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_102 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_103 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_104 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_105 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_106 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_107 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_108 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_109 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_110 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_111 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_112 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_113 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_114 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_115 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_116 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_117 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_118 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_119 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_120 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_121 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_122 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_123 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_124 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_125 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_126 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_127 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_128 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_129 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_130 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_131 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_132 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_133 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_134 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_135 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_136 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_137 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_138 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_139 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_140 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_141 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_142 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_143 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_144 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_145 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_146 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_147 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_148 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_149 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_150 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_151 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_152 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_153 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_154 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_155 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_156 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_157 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_158 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_159 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_160 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_161 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_162 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_163 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_164 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_165 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_166 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_167 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_168 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_169 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_170 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_171 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_172 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_173 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_174 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_175 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_176 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_177 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_178 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_179 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_180 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_181 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_182 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_183 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_184 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_185 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_186 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_187 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_188 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_189 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_190 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_191 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_192 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_193 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_194 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_195 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_196 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_197 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_198 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_199 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_200 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_201 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_202 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_203 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_204 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_205 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_206 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_207 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_208 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_209 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_210 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,
#     index_211 <class 'pynwb.icephys.VoltageClampStimulusSeries'>
#   }
#   subject: subject pynwb.file.Subject at 0x140498991294832
# Fields:
#   description: {'cell type': 'nan', 'length (µm)': 1007.8115999999998, 'width (µm)': 42.3846, 'area (µm)': 197.79479999999998}
#   genotype: unc-8; deg-1, osm-10:rtIs97
#   species: C. elegans
#   subject_id: ASH301
#
#   sweep_table: sweep_table <class 'pynwb.icephys.SweepTable'>
#   timestamps_reference_time: 2010-03-19 06:37:08.042999+00:00
